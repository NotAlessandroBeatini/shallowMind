# %%
# --- 1. list all repos whose ID contains a keyword ------------
from datasets import get_dataset_infos
from huggingface_hub import list_datasets

def search(keyword, limit=20):
    print(f"\n🔍 searching '{keyword}' …")
    for ds in list_datasets(search=keyword, limit=limit):
        print(" ", ds.id)

search("refinedweb")
search("refined-web")
search("refined_web")
search("slimpajama")
search("dolma")
search("redpajama")
# Out:
# 🔍 searching 'refinedweb' …
#   tiiuae/falcon-refinedweb
#   crumb/flan-t5-small-embed-refinedweb
#   crumb/flan-t5-base-embed-refinedweb
#   crumb/flan-t5-large-embed-refinedweb
#   crumb/flan-t5-xl-embed-refinedweb
#   mattymchen/refinedweb-3m
#   andersonbcdefg/falcon-refinedweb-labeled
#   crumb/refinedweb-2mil-128clusters
#   crumb/refinedweb-22mil-128clusters
#   mponty/refinedweb_docs
#   BEE-spoke-data/falcon-refinedweb-100k_en_med-sample
#   BEE-spoke-data/falcon-refinedweb-1M_en_medium
#   BEE-spoke-data/falcon-refinedweb-100k_en-long
#   BEE-spoke-data/falcon-refinedweb-100k_en-xlong
#   pinecone/refinedweb-generated-questions
#   vilm/refinedweb-1m-medium
#   kenhktsui/refinedweb-3m_quality_score_v1
#   chaoscodes/refinedweb-500
#   orionweller/refinedweb_mds_incremental
#   mlfoundations/refinedweb_banned_domains_curated
#
# 🔍 searching 'refined-web' …
#   tiiuae/falcon-refinedweb
#   crumb/flan-t5-small-embed-refinedweb
#   crumb/flan-t5-base-embed-refinedweb
#   crumb/flan-t5-large-embed-refinedweb
#   crumb/flan-t5-xl-embed-refinedweb
#   mattymchen/refinedweb-3m
#   Jackmin108/bert-base-uncased-refined-web-segment0
#   andersonbcdefg/falcon-refinedweb-labeled
#   crumb/refinedweb-2mil-128clusters
#   crumb/refinedweb-22mil-128clusters
#   mponty/refinedweb_docs
#   BEE-spoke-data/falcon-refinedweb-100k_en_med-sample
#   BEE-spoke-data/falcon-refinedweb-1M_en_medium
#   BEE-spoke-data/falcon-refinedweb-100k_en-long
#   BEE-spoke-data/falcon-refinedweb-100k_en-xlong
#   pinecone/refinedweb-generated-questions
#   vilm/refinedweb-1m-medium
#   kenhktsui/refinedweb-3m_quality_score_v1
#   sazirarrwth99/web_nlg_enriched_refined_new_03
#   sazirarrwth99/web_nlg_enriched_refined_85_percent
#
# 🔍 searching 'refined_web' …
#   tiiuae/falcon-refinedweb
#   crumb/flan-t5-small-embed-refinedweb
#   crumb/flan-t5-base-embed-refinedweb
#   crumb/flan-t5-large-embed-refinedweb
#   crumb/flan-t5-xl-embed-refinedweb
#   mattymchen/refinedweb-3m
#   Jackmin108/bert-base-uncased-refined-web-segment0
#   andersonbcdefg/falcon-refinedweb-labeled
#   crumb/refinedweb-2mil-128clusters
#   crumb/refinedweb-22mil-128clusters
#   mponty/refinedweb_docs
#   BEE-spoke-data/falcon-refinedweb-100k_en_med-sample
#   BEE-spoke-data/falcon-refinedweb-1M_en_medium
#   BEE-spoke-data/falcon-refinedweb-100k_en-long
#   BEE-spoke-data/falcon-refinedweb-100k_en-xlong
#   pinecone/refinedweb-generated-questions
#   vilm/refinedweb-1m-medium
#   kenhktsui/refinedweb-3m_quality_score_v1
#   sazirarrwth99/web_nlg_enriched_refined_new_03
#   sazirarrwth99/web_nlg_enriched_refined_85_percent
#
# 🔍 searching 'slimpajama' …
#   cerebras/SlimPajama-627B
#   crumb/neox-slimpajama-ul2-small-testing
#   DKYoon/SlimPajama-6B
#   rwkv-x-dev/slimpajama-world-tokenized
#   AlppAI/SlimPajama-chunked
#   open-llm-leaderboard-old/details_bigcode-data__slimpajama-1.3b
#   rwkv-x-dev/slimpajama-binidx
#   MBZUAI-LLM/SlimPajama-627B-DC
#   sproos/SlimPajama-6B-embedded
#   rokset3/slimpajama
#   rokset3/slim_pajama_627b
#   rokset3/slim_pajama_chunk1
#   rokset3/slim_pajama_chunk_1
#   rokset3/slim_pajama_chunk_2
#   rokset3/slim_pajama_chunk_3
#   rokset3/slim_pajama_chunk_4
#   rokset3/slim_pajama_chunk_5
#   venketh/SlimPajama-62B
#   qywu/slimpajama_long
#   crumb/tiny-slimpajama-k8-00001
#
# 🔍 searching 'dolma' …
#   allenai/dolma
#   Elain-q/dolma_low_quality_data
#   iohadrubin/dolma_cc
#   allenai/dolma_tagger_analysis
#   andersonbcdefg/dolma_sample
#   yuntian-deng/dolmasample
#   devingulliver/dolma-v1_6-sample
#   agentlans/dolma-1m
#   emozilla/dolma-v1_7-305B
#   emozilla/dolma-v1_7-30B
#   emozilla/dolma-v1_7-30B-tokenized-llama3-nanoset
#   emozilla/dolma-v1_7-305B-tokenized-llama3-nanoset
#   orionweller/dolma_20_percent_sample
#   emozilla/dolma-v1_7-3B-tokenized-llama3-nanoset
#   emozilla/dolma-v1_7-3B
#   emozilla/dolma-v1_7-algebraic-stack-train
#   emozilla/dolma-v1_7-arxiv
#   emozilla/dolma-v1_7-books
#   emozilla/dolma-v1_7-c4
#   emozilla/dolma-v1_7-cc_en_head
#
# 🔍 searching 'redpajama' …
#   togethercomputer/RedPajama-Data-1T-Sample
#   datajuicer/redpajama-book-refined-by-data-juicer
#   togethercomputer/RedPajama-Data-1T
#   Fredithefish/Instruction-Tuning-with-GPT-4-RedPajama-Chat
#   Fredithefish/GPTeacher-for-RedPajama-Chat
#   Fredithefish/ShareGPT-Unfiltered-RedPajama-Chat-format
#   togethercomputer/RedPajama-Data-Instruct
#   Fredithefish/hh-rlhf-RedPajama-Chat-Format
#   xufana/RedPajama-INCITE-Instruct-3B-Addition
#   Abzu/RedPajama-Data-1T-arxiv-filtered
#   sippycoder/RedPajama-Data-1T-no-cc-c4
#   ivanzhouyq/RedPajama-Tiny
#   open-llm-leaderboard-old/details_acrastt__RedPajama-INCITE-Chat-Instruct-3B-V1
#   open-llm-leaderboard-old/details_Fredithefish__RedPajama-INCITE-Chat-3B-Instruction-Tuning-with-GPT-4
#   open-llm-leaderboard-old/details_Fredithefish__RedPajama-INCITE-Chat-3B-ShareGPT-11K
#   open-llm-leaderboard-old/details_togethercomputer__RedPajama-INCITE-Instruct-7B-v0.1
#   open-llm-leaderboard-old/details_togethercomputer__RedPajama-INCITE-Chat-3B-v1
#   open-llm-leaderboard-old/details_togethercomputer__RedPajama-INCITE-Base-3B-v1
#   open-llm-leaderboard-old/details_togethercomputer__RedPajama-INCITE-7B-Base
#   open-llm-leaderboard-old/details_togethercomputer__RedPajama-INCITE-7B-Chat

# %%
# --- 2. show configs for a candidate repo --------------------
from datasets import get_dataset_config_names

repo = "allenai/dolma"          # edit and re-run
print(repo, "configs →", get_dataset_config_names(repo))
# Out:
# allenai/dolma configs → ['v1', 'v1_5', 'v1_5-sample', 'v1_6', 'v1_6-sample', 'v1_7']

# %%
from huggingface_hub import (
    list_repo_files,           # enumerate every object in the repo
    hf_hub_url,                # build its download URL
    get_hf_file_metadata,      # fetch the HEAD metadata
)

repo_id = "tiiuae/falcon-refinedweb"
repo_type = "dataset"

safe_files = []
unsafe_files = []

for fp in list_repo_files(repo_id, repo_type=repo_type):
    url = hf_hub_url(repo_id, fp, repo_type=repo_type)
    meta = get_hf_file_metadata(url)          # <-- only the URL goes here

    # The Hub adds an extra header `x-amz-meta-virus-scan-result`
    # for every file it has scanned with ClamAV.
    scan_result = getattr(meta, "virus_scan_result", None)

    if scan_result in (None, "ok"):           # 'None' = not scanned yet
        safe_files.append(fp)
    elif scan_result == "infected":
        unsafe_files.append(fp)
    else:
        print(f"[warn] unexpected value {scan_result!r} on {fp}")
